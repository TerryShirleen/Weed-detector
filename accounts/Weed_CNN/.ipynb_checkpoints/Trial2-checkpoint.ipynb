# %%
import tensorflow as tf
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for tensorflow from https://files.pythonhosted.org/packages/80/6f/57d36f6507e432d7fc1956b2e9e8530c5c2d2bfcd8821bcbfae271cd6688/tensorflow-2.14.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow-2.14.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# ...
#   Obtaining dependency information for tensorflow-intel==2.14.0 from https://files.pythonhosted.org/packages/ad/6e/1bfe367855dd87467564f7bf9fa14f3b17889988e79598bc37bf18f5ffb6/tensorflow_intel-2.14.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.14.0-cp311-cp311-win_amd64.whl.metadata (4.8 kB)
# ...
#   Obtaining dependency information for absl-py>=1.0.0 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...

# %%
# !pip install numpy

# %%
C:\Users\Lenovo\Desktop\WeedCrop.v1i.yolov5pytorch\test\labels
    
    
train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input) \
    .flow_from_directory(directory=train_dir, target_size=(224,224), classes=['weed', 'not weed'], batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input) \
    .flow_from_directory(directory=valid_dir, target_size=(224,224), classes=['weed', 'not weed'], batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input) \
    .flow_from_directory(directory=test_dir, target_size=(224,224), classes=['weed', 'not weed'], batch_size=10, shuffle=False)
# Out:
#   Cell In[1], line 1
#     C:\Users\Lenovo\Desktop\WeedCrop.v1i.yolov5pytorch\test\labels
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
desired_size = (150, 150)
train_dir = "C:/Users/Lenovo/Desktop/Weed_CNN/WeedCrop.v1i.yolov5pytorch/train"

# Create a list of image file paths in the training directory
image_paths = [os.path.join(train_dir, class_name, image_name) for class_name in os.listdir(train_dir) for image_name in os.listdir(os.path.join(train_dir, class_name))]

# Function to load and convert an image to a numerical array
# Function to load and convert an image to a numerical array
def image_to_array(image_path, desired_size):
    image = cv2.imread(image_path)
    # Resize the image to the desired size
    image = cv2.resize(image, desired_size)
    # Convert the image to a numerical array (NumPy array)
    image_array = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB (optional)
    return image_array

# List to store numerical arrays of images
image_arrays = []

# Loop through each image in the training dataset and convert them to numerical arrays
for image_path in image_paths:
    image_array = image_to_array(image_path, desired_size)
    image_arrays.append(image_array)

# Stack the image arrays into a single NumPy array
image_arrays = np.array(image_arrays)

# Display the shape of the resulting array (num_images, height, width, channels)
print(image_arrays.shape)
